# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# %%
data_path = r'C:\Users\X280\Downloads'
df = pd.read_csv(data_path + r'\datavarsmall.csv', header=0)

# %%
df
# Out:
#        target  precision    recall  f1-score  TP  FP  FN  TN  \
# 0           0        1.0  0.166667  0.285714   1   0   5   4
# 1           1        0.0  0.000000       NaN   0   1   6   3
# 2           2        1.0  0.166667  0.285714   1   0   5   4
# 3           3        1.0  0.166667  0.285714   1   0   5   4
# 4           4        1.0  0.166667  0.285714   1   0   5   4
# ...       ...        ...       ...       ...  ..  ..  ..  ..
# 17595       5        0.6  1.000000  0.750000   6   4   0   0
# 17596       6        0.6  1.000000  0.750000   6   4   0   0
# 17597       7        0.6  1.000000  0.750000   6   4   0   0
# 17598       8        0.6  1.000000  0.750000   6   4   0   0
# 17599       9        0.6  1.000000  0.750000   6   4   0   0
#
#        Selected_features  Lags           Dataset   File_name  Execution_time  \
# 0                      1     1  VARSmall/returns  data_0.csv       15.696159
# ...

# %%
df.describe()
# Out:
#              target     precision        recall      f1-score            TP  \
# count  17600.000000  17600.000000  17600.000000  17420.000000  17600.000000
# mean       4.500000      0.610733      0.847907      0.692805      5.087443
# std        2.872363      0.119179      0.251205      0.129580      1.507231
# min        0.000000      0.000000      0.000000      0.181818      0.000000
# 25%        2.000000      0.600000      0.833333      0.666667      5.000000
# 50%        4.500000      0.600000      1.000000      0.750000      6.000000
# 75%        7.000000      0.600000      1.000000      0.750000      6.000000
# max        9.000000      1.000000      1.000000      1.000000      6.000000
#
#                  FP            FN            TN  Selected_features  \
# count  17600.000000  17600.000000  17600.000000       17600.000000
# mean       3.317727      0.912557      0.682273          36.420455
# std        1.132188      1.507231      1.132188          28.010016
# ...

# %%
g = sns.FacetGrid(df, col="FS_SIZE", col_wrap=3)
g.map(sns.boxplot, "File_name", "f1-score")
# Out:
# C:\Users\X280\OneDrive\Documents\lib\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
ax=sns.lineplot(data=df,x='Selected_features',y='precision',label='Precision')
ax2=sns.lineplot(data=df,x='Selected_features',y='recall',label='Recall')
plt.ylabel("Precison & Recall ")
# Out:
# Text(0, 0.5, 'Precison & Recall ')

# %%
sns.lineplot(data=df, x='FS_SIZE', y='precision',label='Precision')
sns.lineplot(data=df, x='FS_SIZE', y='recall',label='Recall')
plt.ylabel("Precision & Recall")
# Out:
# Text(0, 0.5, 'Precision & Recall')

# %%
sns.lineplot(data=df, x='Lags', y='precision', label='Précision')
sns.lineplot(data=df, x='Lags', y='recall', label='Rappel')
plt.ylabel("Precision & Recall")
# Out:
# Text(0, 0.5, 'Precision & Recall')

# %%
sns.set_theme(style="whitegrid")
g = sns.catplot(
    data=df, kind="bar",
    x="Lags", y="precision", hue="File_name",
    errorbar="sd",palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("Lags", "Precision")
g.legend.set_title("")

# %%
sns.set_theme(style="whitegrid")
h = sns.catplot(
    data=df, kind="bar",
    x="Lags", y="recall", hue="File_name",
    errorbar="sd",palette="dark", alpha=.6, height=6
)
h.despine(left=True)
h.set_axis_labels("Lags", "Recall")
h.legend.set_title("")

# %%
sns.set_theme(style="whitegrid")
h = sns.catplot(
    data=df, kind="bar",
    x="Lags", y="recall", hue="target",
    errorbar="sd",palette="dark", alpha=.6, height=6
)
h.despine(left=True)
h.set_axis_labels("Lags", "Recall")
h.legend.set_title("")

# %%
sns.set_theme(style="whitegrid")
h = sns.catplot(
    data=df, kind="bar",
    x="Lags", y="precision", hue="target",
    errorbar="sd",palette="dark", alpha=.6, height=6
)
h.despine(left=True)
h.set_axis_labels("Lags", "Precision")
h.legend.set_title("")

# %%
data_path2 = r'C:\Users\X280\Desktop\Python projects\projets2A'
df2 = pd.read_csv(data_path +r'\final_data_frame_2.csv', header=0)

# %%
df2
# Out:
#      target  precision  recall  f1-score  TP  FP  FN  TN  Selected_features  \
# 0         E   1.000000     0.5  0.666667   1   0   1   5                  1
# 1         B   1.000000     0.5  0.666667   1   0   1   5                  1
# 2         F   1.000000     0.5  0.666667   1   0   1   5                  1
# 3         C   1.000000     1.0  1.000000   1   0   0   6                  1
# 4         H   1.000000     0.5  0.666667   1   0   1   5                  1
# ...     ...        ...     ...       ...  ..  ..  ..  ..                ...
# 8535      F   0.285714     1.0  0.444444   2   5   0   0                 69
# 8536      C   0.142857     1.0  0.250000   1   6   0   0                 69
# 8537      H   0.285714     1.0  0.444444   2   5   0   0                 69
# 8538      D   0.285714     1.0  0.444444   2   5   0   0                 69
# 8539      A   0.285714     1.0  0.444444   2   5   0   0                 69
#
# ...

# %%
ax=sns.lineplot(data=df2,x='Selected_features',y='precision',label='Precision')
ax2=sns.lineplot(data=df2,x='Selected_features',y='recall',label='Recall')
plt.ylabel("Precison & Recall ")
# Out:
# Text(0, 0.5, 'Precison & Recall ')

# %%
sns.lineplot(data=df2, x='FS_size', y='precision',label='Precision')
sns.lineplot(data=df2, x='FS_size', y='recall',label='Recall')
plt.ylabel("Precision & Recall")
# Out:
# Text(0, 0.5, 'Precision & Recall')

# %%
sns.lineplot(data=df2, x='Lags', y='precision', label='Précision')
sns.lineplot(data=df2, x='Lags', y='recall', label='Rappel')
plt.ylabel("Precision & Recall")
# Out:
# Text(0, 0.5, 'Precision & Recall')

# %%
sns.set_theme(style="whitegrid")
g = sns.catplot(
    data=df2, kind="bar",
    x="Lags", y="precision", hue="File_name",
    errorbar="sd",palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("Lags", "Precision")
g.legend.set_title("")

# %%
sns.set_theme(style="whitegrid")
h = sns.catplot(
    data=df2, kind="bar",
    x="Lags", y="recall", hue="File_name",
    errorbar="sd",palette="dark", alpha=.6, height=6
)
h.despine(left=True)
h.set_axis_labels("Lags", "Recall")
h.legend.set_title("")

# %%
sns.set_theme(style="whitegrid")
h = sns.catplot(
    data=df2, kind="bar",
    x="Lags", y="recall", hue="target",
    errorbar="sd",palette="dark", alpha=.6, height=6
)
h.despine(left=True)
h.set_axis_labels("Lags", "Recall")
h.legend.set_title("")

# %%
sns.set_theme(style="whitegrid")
h = sns.catplot(
    data=df2, kind="bar",
    x="Lags", y="precision", hue="target",
    errorbar="sd",palette="dark", alpha=.6, height=6
)
h.despine(left=True)
h.set_axis_labels("Lags", "Precision")
h.legend.set_title("")
